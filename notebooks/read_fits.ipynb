# %%
from src.io import load_fits, header_to_dataframe

# %%
data, header = load_fits("../data/_10_03_54Z_SOLEX_82_530_N_SKY-82ED_ZWO-AZ183_10M-GM3000_Ha_20260205_100354.fits")

# %%
print(data.shape)
# Out:
# (4096, 4096)

# %%
df_header = header_to_dataframe(header)
df_header.head
